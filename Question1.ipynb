# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffrgh/DAA/blob/main/Question1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file_to_read = "sample_text.txt"

try:
    with open(file_to_read, 'r') as file:
        content = file.read()
        print("Successfully read from file. Content:")
        print(content)

except FileNotFoundError:
    print(f"Error: The file '{file_to_read}' was not found.")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
